# %%
import requests
from langchain_deepseek import ChatDeepSeek
import os
import json
import re
from collections import defaultdict

os.environ["DEEPSEEK_API_KEY"] = ""
os.environ["DEEPSEEK_BASE_URL"] = "https://api.deepseek.com"
llm = ChatDeepSeek(model="deepseek-chat", temperature=0, max_tokens=5)

data_folder = 'data'
output_folder = 'results/12deepseek-v3'
os.makedirs(output_folder, exist_ok=True)

# %%
def process_data_file(file_path):
    """处理单个JSON文件"""
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    questions = data["questions"]
    skip_ids = set(map(str, data["skip"]))
    file_name = data["title"]
    print(f"\n正在处理文件: {file_name}")

    # 统计题型
    type_counts = defaultdict(int)
    for question in questions:
        if question["id"] not in skip_ids:
            type_counts[question["type"]] += 1

    print("\n各题型题数统计 (剔除skip题):")
    for type_name, count in type_counts.items():
        print(f"{type_name}: {count}题")
    print(f"\n总题数 (剔除skip题): {sum(type_counts.values())}")
    print(f"跳过的题数: {len(skip_ids)}")

    def predict_answer(question_data):
        """预测单个问题的答案"""
        question_text = question_data["question"]
        if question_data["options"]:  # 有选项
            options_text = "\n".join([f"{k}、{v}" for k, v in question_data["options"].items()])
            full_question = f"{question_text}\n{options_text}"
        else:
            full_question = question_text  # 没有选项
        
        prompt = f"""
        请根据题目内容选择最合适的答案。只需返回选项字母，不要包含其他任何内容！

        题目：
        {full_question}
        """
        response = llm.invoke(prompt)
        # 提取选项字母
        pred_answer = response.content.strip()
        match = re.search(r'([A-D]+)', pred_answer.upper())
        if match:
            return match.group(1)
        return pred_answer

    # 处理题目
    results = []
    correct = 0
    total_processed = 0
    type_stats = defaultdict(lambda: {'correct': 0, 'total': 0})

    for q in questions:
        if q["id"] in skip_ids or "answer" not in q:
            continue 
        
        total_processed += 1
        
        try:
            pred_answer = predict_answer(q)
            true_answer = q["answer"]
            is_correct = pred_answer == true_answer
            
            if is_correct:
                correct += 1
            
            question_type = q["type"]
            type_stats[question_type]['total'] += 1
            if is_correct:
                type_stats[question_type]['correct'] += 1
            
            results.append({
                "id": q["id"],
                "type": q["type"],
                "question": q["question"],
                "options": q["options"],
                "true_answer": true_answer,
                "pred_answer": pred_answer,
                "is_correct": is_correct
            })
                
        except Exception as e:
            print(f"Error processing question {q['id']}: {e}")
            question_type = q["type"]
            type_stats[question_type]['total'] += 1
            
            results.append({
                "id": q["id"],
                "type": q["type"],
                "question": q["question"],
                "options": q["options"],
                "true_answer": q.get("answer", ""),
                "pred_answer": "ERROR",
                "is_correct": False,
                "error": str(e)
            })

    # 计算准确率
    accuracy = correct / total_processed if total_processed > 0 else 0
    type_accuracies = {}
    for type_name, stats in type_stats.items():
        type_total = stats['total']
        type_correct = stats['correct']
        type_accuracies[type_name] = {
            'accuracy': type_correct / type_total if type_total > 0 else 0,
            'correct': type_correct,
            'total': type_total
        }

    print(f"\n总体准确率(剔除skip题目): {accuracy:.2%} ({correct}/{total_processed})")
    print("\n各题型准确率:")
    for type_name, acc in type_accuracies.items():
        print(f"{type_name}: {acc['accuracy']:.2%} ({acc['correct']}/{acc['total']})")

    # 保存结果
    output_file = os.path.join(output_folder, f"{file_name}.json")
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump({
            "title": data["title"],
            "skip": data["skip"],
            "overall_accuracy": accuracy,
            "total_processed_questions": total_processed,
            "correct_answers": correct,
            "skipped_questions": len(skip_ids),
            "type_accuracies": type_accuracies,
            "results": results
        }, f, ensure_ascii=False, indent=2)

    print(f"预测结果已保存到 {output_file}")

# %%
# 处理data文件夹下的所有JSON文件
print(f"开始处理 {data_folder} 文件夹下的所有JSON文件...")
for filename in os.listdir(data_folder):
    if filename.endswith('.json'):
        file_path = os.path.join(data_folder, filename)
        try:
            process_data_file(file_path)
        except Exception as e:
            print(f"处理文件 {filename} 时出错: {e}")
print("\n所有文件处理完成!")
# Out:
# 开始处理 data 文件夹下的所有JSON文件...
#
# 正在处理文件: 2024年国家公务员录用考试《行测》题（副省级网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 20题
# 表达理解: 30题
# 数量关系: 13题
# 判断推理: 29题
#
# 总题数 (剔除skip题): 92
# 跳过的题数: 43
#
# 总体准确率(剔除skip题目): 75.00% (69/92)
#
# 各题型准确率:
# 常识判断: 90.00% (18/20)
# 表达理解: 90.00% (27/30)
# 数量关系: 23.08% (3/13)
# 判断推理: 72.41% (21/29)
# 预测结果已保存到 results/12deepseek-v3\2024年国家公务员录用考试《行测》题（副省级网友回忆版）.json
#
# 正在处理文件: 2025年国家公务员录用考试《行测》题（副省级网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 政治理论: 20题
# 常识判断: 15题
# 表达理解: 20题
# 数量关系: 14题
# 判断推理: 24题
#
# 总题数 (剔除skip题): 93
# 跳过的题数: 42
#
# 总体准确率(剔除skip题目): 68.82% (64/93)
#
# 各题型准确率:
# 政治理论: 95.00% (19/20)
# 常识判断: 73.33% (11/15)
# 表达理解: 95.00% (19/20)
# 数量关系: 7.14% (1/14)
# 判断推理: 58.33% (14/24)
# 预测结果已保存到 results/12deepseek-v3\2025年国家公务员录用考试《行测》题（副省级网友回忆版）.json
#
# 正在处理文件: 2023年国家公务员录用考试《行测》题（副省级网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 20题
# 表达理解: 30题
# 数量关系: 14题
# 判断推理: 28题
#
# 总题数 (剔除skip题): 92
# 跳过的题数: 43
#
# 总体准确率(剔除skip题目): 72.83% (67/92)
#
# 各题型准确率:
# 常识判断: 95.00% (19/20)
# 表达理解: 73.33% (22/30)
# 数量关系: 21.43% (3/14)
# 判断推理: 82.14% (23/28)
# 预测结果已保存到 results/12deepseek-v3\2023年国家公务员录用考试《行测》题（副省级网友回忆版）.json
#
# 正在处理文件: 2024年福建省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 18题
# 言语理解与表达: 40题
# 数量关系: 7题
# 判断推理: 30题
# 资料分析: 5题
#
# 总题数 (剔除skip题): 100
# 跳过的题数: 20
#
# 总体准确率(剔除skip题目): 75.00% (75/100)
#
# 各题型准确率:
# 常识判断: 83.33% (15/18)
# 言语理解与表达: 92.50% (37/40)
# 数量关系: 42.86% (3/7)
# 判断推理: 56.67% (17/30)
# 资料分析: 60.00% (3/5)
# 预测结果已保存到 results/12deepseek-v3\2024年福建省公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年广东省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 10题
# 言语理解与表达: 15题
# 数量关系: 14题
# 判断推理: 15题
# 科学推理: 1题
# 资料分析: 5题
#
# 总题数 (剔除skip题): 60
# 跳过的题数: 30
#
# 总体准确率(剔除skip题目): 68.33% (41/60)
#
# 各题型准确率:
# 常识判断: 40.00% (4/10)
# 言语理解与表达: 93.33% (14/15)
# 数量关系: 57.14% (8/14)
# 判断推理: 66.67% (10/15)
# 科学推理: 100.00% (1/1)
# 资料分析: 80.00% (4/5)
# 预测结果已保存到 results/12deepseek-v3\2024年广东省公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年广西区考公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 10题
# 言语理解与表达: 35题
# 数量关系: 7题
# 判断推理: 30题
#
# 总题数 (剔除skip题): 82
# 跳过的题数: 28
#
# 总体准确率(剔除skip题目): 71.95% (59/82)
#
# 各题型准确率:
# 常识判断: 90.00% (9/10)
# 言语理解与表达: 85.71% (30/35)
# 数量关系: 42.86% (3/7)
# 判断推理: 56.67% (17/30)
# 预测结果已保存到 results/12deepseek-v3\2024年广西区考公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年海南省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 19题
# 言语理解与表达: 30题
# 数量关系: 12题
# 判断推理: 22题
#
# 总题数 (剔除skip题): 83
# 跳过的题数: 27
#
# 总体准确率(剔除skip题目): 71.08% (59/83)
#
# 各题型准确率:
# 常识判断: 84.21% (16/19)
# 言语理解与表达: 90.00% (27/30)
# 数量关系: 33.33% (4/12)
# 判断推理: 54.55% (12/22)
# 预测结果已保存到 results/12deepseek-v3\2024年海南省公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年湖北省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 20题
# 言语理解与表达: 35题
# 数量关系: 10题
# 判断推理: 30题
#
# 总题数 (剔除skip题): 95
# 跳过的题数: 30
#
# 总体准确率(剔除skip题目): 73.68% (70/95)
#
# 各题型准确率:
# 常识判断: 75.00% (15/20)
# 言语理解与表达: 82.86% (29/35)
# 数量关系: 20.00% (2/10)
# 判断推理: 80.00% (24/30)
# 预测结果已保存到 results/12deepseek-v3\2024年湖北省公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年湖南省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 14题
# 言语理解与表达: 40题
# 数量关系: 9题
# 判断推理: 30题
#
# 总题数 (剔除skip题): 93
# 跳过的题数: 27
#
# 总体准确率(剔除skip题目): 75.27% (70/93)
#
# 各题型准确率:
# 常识判断: 78.57% (11/14)
# 言语理解与表达: 92.50% (37/40)
# 数量关系: 44.44% (4/9)
# 判断推理: 60.00% (18/30)
# 预测结果已保存到 results/12deepseek-v3\2024年湖南省公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年江西省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 25题
# 言语理解与表达: 40题
# 数量关系: 10题
# 判断推理: 30题
# 资料分析: 5题
#
# 总题数 (剔除skip题): 110
# 跳过的题数: 25
#
# 总体准确率(剔除skip题目): 77.27% (85/110)
#
# 各题型准确率:
# 常识判断: 84.00% (21/25)
# 言语理解与表达: 82.50% (33/40)
# 数量关系: 30.00% (3/10)
# 判断推理: 83.33% (25/30)
# 资料分析: 60.00% (3/5)
# 预测结果已保存到 results/12deepseek-v3\2024年江西省公务员录用考试《行测》题（网友回忆版）.json
#
# 正在处理文件: 2024年山东省公务员录用考试《行测》试题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识: 19题
# 言语理解与表达: 30题
# 数量关系: 10题
# 判断推理: 31题
# 资料分析: 5题
#
# 总题数 (剔除skip题): 95
# 跳过的题数: 25
#
# 总体准确率(剔除skip题目): 69.47% (66/95)
#
# 各题型准确率:
# 常识: 89.47% (17/19)
# 言语理解与表达: 80.00% (24/30)
# 数量关系: 30.00% (3/10)
# 判断推理: 61.29% (19/31)
# 资料分析: 60.00% (3/5)
# 预测结果已保存到 results/12deepseek-v3\2024年山东省公务员录用考试《行测》试题（网友回忆版）.json
#
# 正在处理文件: 2024年陕西省公务员录用考试《行测》题（网友回忆版）
#
# 各题型题数统计 (剔除skip题):
# 常识判断: 20题
# 言语理解与表达: 40题
# 判断推理: 25题
# 数量关系: 7题
# 资料分析: 5题
#
# 总题数 (剔除skip题): 97
# 跳过的题数: 23
#
# 总体准确率(剔除skip题目): 77.32% (75/97)
#
# 各题型准确率:
# 常识判断: 80.00% (16/20)
# 言语理解与表达: 85.00% (34/40)
# 判断推理: 80.00% (20/25)
# 数量关系: 14.29% (1/7)
# 资料分析: 80.00% (4/5)
# 预测结果已保存到 results/12deepseek-v3\2024年陕西省公务员录用考试《行测》题（网友回忆版）.json
#
# 所有文件处理完成!
